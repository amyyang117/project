# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import getpass

# %%
def d(line):
    l = '.'.join(line.split())
    return l

options = webdriver.ChromeOptions()
prefs = {'profile.default_content_setting_values':{'notifications': 1}}
options.add_experimental_option('prefs', prefs)

#輸入帳密
email = input("請輸入帳號")
password = getpass.getpass("請輸入密碼")

#打開瀏覽器
driver = webdriver.Chrome('./chromedriver',options=options)
driver.get("http://www.facebook.com")

#登入by class name
input1 = driver.find_element_by_class_name('inputtext._55r1._6luy')
input1.send_keys(email)

input2 = driver.find_element_by_class_name('inputtext._55r1._6luy._9npi')
input2.send_keys(password)

password = 0
driver.find_element_by_class_name('_42ft._4jy0._6lth._4jy6._4jy1.selected._51sy').click()
# Out:
# 請輸入帳號amyyang20000107@yahoo.com.tw
# 請輸入密碼········

# %%
# go to specific page
url = 'https://www.facebook.com/groups/808065716041098/?multi_permalinks=1845867072260952%2C1845828008931525%2C1845825975598395%2C1845768885604104%2C1845714092276250&notif_id=1619506442367667&notif_t=group_activity&ref=notif'
driver.get(url)
#尋找查看更多按下去
page=0  
while page <5:
    
    c= driver.find_elements_by_class_name(d('g5ia77u1 qu0x051f esr5mh6w e9989ue4 r7d6kgcz rq0escxv nhd2j8a9 nc684nl6 p7hjln8o kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x jb3vyjys rz4wbd8a qt6c0cv9 a8nywdso i1ao9s8h esuyzwwr f1sip0of lzcic4wl oo9gr5id gpro0wi8 lrazzd5p'))
    for i in c:
        if i.text =='查看更多':
            try :
                i.click()
            except Exception:
                pass
    
    content= driver.find_elements_by_class_name(d('o9v6fnle cxmmr5t8 oygrvhab hcukyx3x c1et5uql ii04i59q'))
    for i in content:
        print(i.text)
        
    time.sleep(5)
    
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    page +=1
driver.quit()
# Out:
# [責任]
# 1., 為從登機到下機的工作人員提供人力資源管理服務.
# 2. 處理有關人事活動的檔案並編寫報告.
# 3., 安排面試, 會議和人力資源活動
# 4., 在培訓安排方面提供支援.
# [資格]
# 1. 3-4天/一周
# 2. 至少待8-12個月
# 3. 熟悉Excel & Word
# 4., 詳細關注
# 5., 擅長溝通技巧
# 如果您對這個職位感興趣, 請傳送簡歷to：Ivonne.Tseng@eastspring.com
# *電子郵件標題: 人力資源實習生名稱
# *附上檔案: 簡歷
# （預計收到5/16，先到先審～）
# 這邊主管跟同事人都很好，公司環境也不錯，還有很多小零食可以吃～而且還在信義區交通真的很方便！歡迎大家投遞履歷，有任何問題也都可以問我～
# 專職投資人（航海王）
# 之前媒體引用我的文章做的報導:https://finance.ettoday.net/news/1890366
# 徵求交易助理:
# 工作內容:
# 對帳、查帳、協助處理交易例行事務。
# 工作待遇:
# 35~50k。依學經歷和個人能力調整。 對帳另有對帳獎金。
# 要求:
# 數字感好、熟悉excel、細心、對股票有基本甚至中等程度的了解、高EQ、若有程式能力加分。 快畢業或剛畢業的新鮮人佳。
# 有意應徵者請回答下列兩個問題:
# 1.現在是2021年4月中，你是否有辦法用目前已公布的所有公開資訊，大概預測計算以下三家公司: A.5289宜鼎 B.3481群創 C.6150撼訊。 今年2021年Q1的eps。 預測與計算的邏輯請詳細說明論述。
# 2.是否有投資經驗? 若有，最印象深刻、賺最多、賠最多 的交易經歷 請各自闡述。若無請直接寫無，有無交易經驗並不會增加或降低錄取機率。
# 若對第一個問題沒有頭緒，可以參考:  shorturl.at/syCNU
# 將"財報狗-買雞排懂財務報表"系列的多篇文章看完後，應該就能回答第一題。
# 請將上述兩個問題的回答，連同個人正式履歷與自傳寄到: calolowa@gmail.com
# 招募職缺：活動策畫執行助理(實習、見習生)
# 截止時間：無截止時間，先到先審
# 實…… 查看更多
# 公司組織規模彈性，對於工作上有什麼想法主管都很願意聆聽，歡迎對於FMCG產業有興趣的同學來應徵
# ～～
# 【公司名稱】美商家樂氏Kellogg’s…… 查看更多
# [責任]
# 1., 為從登機到下機的工作人員提供人力資源管理服務.
# 2. 處理有關人事活動的檔案並編寫報告.
# 3., 安排面試, 會議和人力資源活動
# 4., 在培訓安排方面提供支援.
# [資格]
# 1. 3-4天/一周
# 2. 至少待8-12個月
# 3. 熟悉Excel & Word
# 4., 詳細關注
# 5., 擅長溝通技巧
# 如果您對這個職位感興趣, 請傳送簡歷to：Ivonne.Tseng@eastspring.com
# *電子郵件標題: 人力資源實習生名稱
# *附上檔案: 簡歷
# （預計收到5/16，先到先審～）
# 這邊主管跟同事人都很好，公司環境也不錯，還有很多小零食可以吃～而且還在信義區交通真的很方便！歡迎大家投遞履歷，有任何問題也都可以問我～
# 專職投資人（航海王）
# 之前媒體引用我的文章做的報導:https://finance.ettoday.net/news/1890366
# 徵求交易助理:
# 工作內容:
# 對帳、查帳、協助處理交易例行事務。
# 工作待遇:
# 35~50k。依學經歷和個人能力調整。 對帳另有對帳獎金。
# 要求:
# 數字感好、熟悉excel、細心、對股票有基本甚至中等程度的了解、高EQ、若有程式能力加分。 快畢業或剛畢業的新鮮人佳。
# 有意應徵者請回答下列兩個問題:
# 1.現在是2021年4月中，你是否有辦法用目前已公布的所有公開資訊，大概預測計算以下三家公司: A.5289宜鼎 B.3481群創 C.6150撼訊。 今年2021年Q1的eps。 預測與計算的邏輯請詳細說明論述。
# 2.是否有投資經驗? 若有，最印象深刻、賺最多、賠最多 的交易經歷 請各自闡述。若無請直接寫無，有無交易經驗並不會增加或降低錄取機率。
# 若對第一個問題沒有頭緒，可以參考:  shorturl.at/syCNU
# 將"財報狗-買雞排懂財務報表"系列的多篇文章看完後，應該就能回答第一題。
# 請將上述兩個問題的回答，連同個人正式履歷與自傳寄到: calolowa@gmail.com
# 招募職缺：活動策畫執行助理(實習、見習生)
# 截止時間：無截止時間，先到先審
# 實習期間：
# 以暑期為主，時間以平日白天為主，
# 每週至少工作2天，每次3小時
# 排班自由彈性，也可提早上班，經面談可詳談上班時間
# 主要工作内容：
# 1. 協助金融理財相關講座及活動辦理並執行
# 2. 協助輔導考取金融理財相關證照
# 3. 協助金融市場調查
# 4. 學習並帶領"理財桌遊"遊戲，建立並傳達健全正確的理財觀念
# 5. 學習並了解金融理財商品、保險實務內容
# 6. 培養並建立出健全的理財架構
# 7. 主管交辦事項
# 徵求條件：
# 1. 高中職畢業學生(20歲以上、大二以上為佳)
# 2. 勇於嘗試新知、想改變、學習
# 3. 熱情有活力、樂於學習領導能力
# 4. 喜歡辦活動&有活動經驗者佳
# 5. 對於未知事物具好奇心
# 6. 願意並嘗試表達自己的看法
# 7. 想成為金融理財專業人士
# 8. 喜歡金融理財、具備財經背景者尤佳
# 9. 歡迎相關社團負責人及幹部(金融理財相關優先)
# 其他條件：
# 1. 有實務金融理財經驗、對金融理財有極大熱忱尤佳
# 2. 有金融相關證照可加分
# 3. 細心、負責任、能獨立作業
# 4. 學習力旺盛、追求進步
# 工作待遇：基本時薪160元
# 上班地點：台北市中山區長安東路一段27號7樓(南山人壽展新通訊處)
#  福利
# 1. 實習期間上班供餐
# 2. 可協助考取金融理財相關證照(應考相關課程及講義資料應有盡有！)
# 3. 公司所有名師開的金融理財課程講座及分享，免費上、上到飽！
# 4. 若表現優異(考取金融理財相關證照)，提供調高時薪的機會！
# 個人經驗分享
# 相當推薦的一個金融理財實習及見習機會！
# 在這裡的工作，
# 與其說是實習打工，
# 不如說是金融產業的見習！
# 我個人是政大地政系的在學學生，
# 儘管並不是金融理財背景出生的，
# 但透過一次次的實習會議交流分享，
# 以及聆聽講座、產業實務方面的學習，
# 讓身為外行人的我，也能透過耳濡目染，
# 每一天吸取新知不斷學習，
# 並且將這些學習到的新觀念，
# 成為將來個人在做生涯金融理財規劃的基礎，
# 甚至讓我想嘗試領導相關的活動！
# 主管人相當和藹、從業超過30年，
# 因此對於金融理財的完整架構及經驗皆相當了解！
# 此外也相當喜歡並樂於聽年輕人分享！
# 希望可以透過這次開放產業實習的機會教學相長！
# 這裡是個令人感到自在、放鬆、
# 且使人樂於主動學習的環境！
# 來到這邊實習後，我能感受到
# 不但對於自己的生涯理財規劃，有了更深一步的了解之外
# 也更勇於嘗試分享自己的想法了一些！
# 所以樂於分享、樂於領導、樂於學習新知的你
# 請一定不要錯過啦！
#  聯繫方式：
# 請將"履歷表"及"自傳"寄至：
# emilieyeh-2020@nanshanlife.com.tw
# emilieyeh@hotmail.com
# 電話聯繫：0963043431（葉秘書）
# 如果有任何問題，都可以在信件中提出！:)
# 公司組織規模彈性，對於工作上有什麼想法主管都很願意聆聽，歡迎對於FMCG產業有興趣的同學來應徵
# ～～
# 【公司名稱】美商家樂氏Kellogg’s
# 【工作職缺】行銷助理約聘人員
# 【工作內容】
# - Nielsen數據整理及分析
# - 處理銷售資料及業績報表
# - 通路DM/POSM活動發想及製作物管理
# - 協助電商通路業務之進行
# - 其他主管交辦事項
# 【徵求條件】
# 1. 組織能力強，善於發掘問題並快速回報
# 2. 良好的溝通能力與團隊合作
# 3. 良好的資料分析及邏輯能力（Excel)
# 4. 良好的時間管理能力
# 【薪資待遇】月薪27,000-35,000元
# 【工作福利】吃不完的各種麥片及洋芋片，還有機會吃到未上市的新品
# 【工作地點】台北市內湖區內湖路一段314號4樓之1（捷運西湖站附近）
# 【工作時間】星期一到五 9:00-18:00
# 【聯絡方式】
# 若有意願請寄送履歷至nina.chang@kellogg.com
# 對於工作內容有什麼問題也歡迎私訊我喔
# 知名外商 - 內湖 - Shipping Coordinator
# - …… 查看更多
# …… 查看更多
# 【至少需要有工作經驗一年以上, 非PT或實習經歷】
# 部門負責流程改善, 資料分析
# 熟悉PowerBI, python and VBA 經驗佳…… 查看更多
#
#
#
#
#
#
#
#
#
#
#
#
# 招募職缺：活動策畫執行助理(實習、見習生)
# 截止時間：無截止時間，先到先審
# 實習期間：
# 以暑期為主，時間以平日白天為主，
# 每週至少工作2天，每次3小時
# 排班自由彈性，也可提早上班，經面談可詳談上班時間
# 主要工作内容：
# 1. 協助金融理財相關講座及活動辦理並執行
# 2. 協助輔導考取金融理財相關證照
# 3. 協助金融市場調查
# 4. 學習並帶領"理財桌遊"遊戲，建立並傳達健全正確的理財觀念
# 5. 學習並了解金融理財商品、保險實務內容
# 6. 培養並建立出健全的理財架構
# 7. 主管交辦事項
# 徵求條件：
# 1. 高中職畢業學生(20歲以上、大二以上為佳)
# 2. 勇於嘗試新知、想改變、學習
# 3. 熱情有活力、樂於學習領導能力
# 4. 喜歡辦活動&有活動經驗者佳
# 5. 對於未知事物具好奇心
# 6. 願意並嘗試表達自己的看法
# 7. 想成為金融理財專業人士
# 8. 喜歡金融理財、具備財經背景者尤佳
# 9. 歡迎相關社團負責人及幹部(金融理財相關優先)
# 其他條件：
# 1. 有實務金融理財經驗、對金融理財有極大熱忱尤佳
# 2. 有金融相關證照可加分
# 3. 細心、負責任、能獨立作業
# 4. 學習力旺盛、追求進步
# 工作待遇：基本時薪160元
# 上班地點：台北市中山區長安東路一段27號7樓(南山人壽展新通訊處)
#  福利
# 1. 實習期間上班供餐
# 2. 可協助考取金融理財相關證照(應考相關課程及講義資料應有盡有！)
# 3. 公司所有名師開的金融理財課程講座及分享，免費上、上到飽！
# 4. 若表現優異(考取金融理財相關證照)，提供調高時薪的機會！
# 個人經驗分享
# 相當推薦的一個金融理財實習及見習機會！
# 在這裡的工作，
# 與其說是實習打工，
# 不如說是金融產業的見習！
# 我個人是政大地政系的在學學生，
# 儘管並不是金融理財背景出生的，
# 但透過一次次的實習會議交流分享，
# 以及聆聽講座、產業實務方面的學習，
# 讓身為外行人的我，也能透過耳濡目染，
# 每一天吸取新知不斷學習，
# 並且將這些學習到的新觀念，
# 成為將來個人在做生涯金融理財規劃的基礎，
# 甚至讓我想嘗試領導相關的活動！
# 主管人相當和藹、從業超過30年，
# 因此對於金融理財的完整架構及經驗皆相當了解！
# 此外也相當喜歡並樂於聽年輕人分享！
# 希望可以透過這次開放產業實習的機會教學相長！
# 這裡是個令人感到自在、放鬆、
# 且使人樂於主動學習的環境！
# 來到這邊實習後，我能感受到
# 不但對於自己的生涯理財規劃，有了更深一步的了解之外
# 也更勇於嘗試分享自己的想法了一些！
# 所以樂於分享、樂於領導、樂於學習新知的你
# 請一定不要錯過啦！
#  聯繫方式：
# 請將"履歷表"及"自傳"寄至：
# emilieyeh-2020@nanshanlife.com.tw
# emilieyeh@hotmail.com
# 電話聯繫：0963043431（葉秘書）
# 如果有任何問題，都可以在信件中提出！:)
# 公司組織規模彈性，對於工作上有什麼想法主管都很願意聆聽，歡迎對於FMCG產業有興趣的同學來應徵
# ～～
# 【公司名稱】美商家樂氏Kellogg’s
# 【工作職缺】行銷助理約聘人員
# 【工作內容】
# - Nielsen數據整理及分析
# - 處理銷售資料及業績報表
# - 通路DM/POSM活動發想及製作物管理
# - 協助電商通路業務之進行
# - 其他主管交辦事項
# 【徵求條件】
# 1. 組織能力強，善於發掘問題並快速回報
# 2. 良好的溝通能力與團隊合作
# 3. 良好的資料分析及邏輯能力（Excel)
# 4. 良好的時間管理能力
# 【薪資待遇】月薪27,000-35,000元
# 【工作福利】吃不完的各種麥片及洋芋片，還有機會吃到未上市的新品
# 【工作地點】台北市內湖區內湖路一段314號4樓之1（捷運西湖站附近）
# 【工作時間】星期一到五 9:00-18:00
# 【聯絡方式】
# 若有意願請寄送履歷至nina.chang@kellogg.com
# 對於工作內容有什麼問題也歡迎私訊我喔
# 知名外商 - 內湖 - Shipping Coordinator
# - Reporting manager: 美國, 薪資40-55K/per month
# 知名外商 - 內湖 - Demand Planner
# - Report 國外 (Demand Planning Manager), 薪資120萬起
# 期望至少Demand Planner 8年以上工作經驗
# 知名外商 - 桃園 - Sourcing Engineer (年薪70萬至150萬)
# - 熟悉機構料件, 至少8年科技業經驗
# Experience in the Semiconductor Equipment
# 知名外商 - 桃園 - Sr. Supply Chain Specialist (年薪70萬至150萬)
# - 至少8年科技業經驗
# 知名外商 - 桃園 - Buyer (年薪70萬至150萬)
# - 至少5年科技業經驗
# #Buyer #Sourcing #SupplyChain #SCM #Engineer
# #Shipping #MNC #Semicondutor #Equipment
# #採購 #科技業 #半導體 #電子業 #製造 #外商 #設備
# 《吉米會盡可能以最快速度回覆》
# 《沒有合適也可以聊聊留意機會》
# 歡迎私訊或寄履歷至下列信箱: jimmy@recruitexpress.com.tw
# Credit Analyst (月薪落在30至60K)
# 回應:
# √收集公司資訊
# ➤進行基本公司/財務分析
# 進行信用評估.
# √編寫公司基本信用報告
# ➤經理的臨時任務
# 要求:
# ➤經濟/會計/金融學士學位/研究生
# √基本財務/比率分析
# ➤瞭解行業研究
# ➤流利口試/書面英語
# #Credit #Analyst #Finance #MNC
# 《吉米會盡可能以最快速度回覆》
# 《沒有合適也可以聊聊留意機會》
# 歡迎私訊或寄履歷至下列信箱: jimmy@recruitexpress.com.tw
# 【至少需要有工作經驗一年以上, 非PT或實習經歷】
# 部門負責流程改善, 資料分析
# 熟悉PowerBI, python and VBA 經驗佳
# Business Analyst (contractor) 年薪100萬以內
# Experience
# Experience in data-driven consulting or management-information-system (MIS) department of a multinational corporate
# 1-3 year(s) of experience in financial industry (preferred in asset management)
# Fluency in Excel, PowerPoint
# [Preferred] fluency in PowerBI, python and VBA
# #BA #Business #Analyst #Python #VBA #PowerBI
# 《吉米會盡可能以最快速度回覆》
# 《沒有合適也可以聊聊留意機會》
# 歡迎私訊或寄履歷至下列信箱: jimmy@recruitexpress.com.tw
# 今晚....我想來點有挑戰的!
# /…… 查看更多
# 角色和責任:
# •瞭解並遵守公司的檔案控制流程(包括敏捷流程)以及當地物質審查流程
# •領導任何A & P (廣告和宣傳)資產的本地化和翻譯工作…… 查看更多
# 澳台國際投資定位為一小型PE Fund，投資範圍涵蓋台灣市場的財務性、策略性股權投資，關注產業包括農食供應鏈、垂直型電商、餐廳科技等。另外，澳台於2020年底收購上櫃公司夠麻吉(8472.TWO) 55%股權，亦協助佈局未來發展的第二成長曲線。
# 公司背後為創辦澳洲品牌Nature’s Care的吳氏家族，家族在澳洲當地經商30年，藉由澳洲當地的有機原材料生產出優質的保養、保健品，並佈局至全球。此外，家族也在澳洲自營酒莊、橄欖田，並致力推廣其衍伸食品。…… 查看更多
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 知名外商 - 內湖 - Shipping Coordinator
# - Reporting manager: 美國, 薪資40-55K/per month
# 知名外商 - 內湖 - Demand Planner
# - Report 國外 (Demand Planning Manager), 薪資120萬起
# 期望至少Demand Planner 8年以上工作經驗
# 知名外商 - 桃園 - Sourcing Engineer (年薪70萬至150萬)
# - 熟悉機構料件, 至少8年科技業經驗
# Experience in the Semiconductor Equipment
# 知名外商 - 桃園 - Sr. Supply Chain Specialist (年薪70萬至150萬)
# - 至少8年科技業經驗
# 知名外商 - 桃園 - Buyer (年薪70萬至150萬)
# - 至少5年科技業經驗
# #Buyer #Sourcing #SupplyChain #SCM #Engineer
# #Shipping #MNC #Semicondutor #Equipment
# #採購 #科技業 #半導體 #電子業 #製造 #外商 #設備
# 《吉米會盡可能以最快速度回覆》
# 《沒有合適也可以聊聊留意機會》
# 歡迎私訊或寄履歷至下列信箱: jimmy@recruitexpress.com.tw
# Credit Analyst (月薪落在30至60K)
# 回應:
# √收集公司資訊
# ➤進行基本公司/財務分析
# 進行信用評估.
# √編寫公司基本信用報告
# ➤經理的臨時任務
# 要求:
# ➤經濟/會計/金融學士學位/研究生
# √基本財務/比率分析
# ➤瞭解行業研究
# ➤流利口試/書面英語
# #Credit #Analyst #Finance #MNC
# 《吉米會盡可能以最快速度回覆》
# 《沒有合適也可以聊聊留意機會》
# 歡迎私訊或寄履歷至下列信箱: jimmy@recruitexpress.com.tw
# 【至少需要有工作經驗一年以上, 非PT或實習經歷】
# 部門負責流程改善, 資料分析
# 熟悉PowerBI, python and VBA 經驗佳
# Business Analyst (contractor) 年薪100萬以內
# Experience
# Experience in data-driven consulting or management-information-system (MIS) department of a multinational corporate
# 1-3 year(s) of experience in financial industry (preferred in asset management)
# Fluency in Excel, PowerPoint
# [Preferred] fluency in PowerBI, python and VBA
# #BA #Business #Analyst #Python #VBA #PowerBI
# 《吉米會盡可能以最快速度回覆》
# 《沒有合適也可以聊聊留意機會》
# 歡迎私訊或寄履歷至下列信箱: jimmy@recruitexpress.com.tw
# 今晚....我想來點有挑戰的!
# /…… 查看更多
# 角色和責任:
# •瞭解並遵守公司的檔案控制流程(包括敏捷流程)以及當地物質審查流程
# •領導任何A & P (廣告和宣傳)資產的本地化和翻譯工作
# •帶領所有創意資產需求季度清單匯編, 與公司合作
# •品牌通訊-直覺的使命, 品牌歷史, 視覺品牌語言(VBL)
# •管理外科醫生, 醫院和病人事件的後勤工作(預算, AV住宿等) )
# •管理與活動, 預售和釋出相關的SFDC /自動化利用
# •全年協調和執行銷售/商業內部會議
# •審查和註冊新供應商, 付款發票管理
# •管理所有分配的競選預算
# 技能, 經驗, 教育和培訓需要學士學位或同等學位• 2多年的會議或活動組織經驗, 醫療裝置產業體驗加
# •醫療裝置或制藥公司的項目管理經驗優先
# •在領導一個中期項目方面表現出成功
# •能夠管理多項任務
# •跨職能工作的人際交流技能
# •需要流利的口頭和書面英語
# •需要電腦技能(微軟單詞, Excel, PowerPoint)
# •旅行能力30 %
# 薪資待遇：月薪50,000以上
# 工作時間：9:00-18:00; 周休二日、必要時配合加班及出差
# 應徵方式：請將履歷投遞至104或IST.HR@intusurg.com
# https://www.104.com.tw/company/1a2x6bl25t
# 澳台國際投資定位為一小型PE Fund，投資範圍涵蓋台灣市場的財務性、策略性股權投資，關注產業包括農食供應鏈、垂直型電商、餐廳科技等。另外，澳台於2020年底收購上櫃公司夠麻吉(8472.TWO) 55%股權，亦協助佈局未來發展的第二成長曲線。
# 公司背後為創辦澳洲品牌Nature’s Care的吳氏家族，家族在澳洲當地經商30年，藉由澳洲當地的有機原材料生產出優質的保養、保健品，並佈局至全球。此外，家族也在澳洲自營酒莊、橄欖田，並致力推廣其衍伸食品。
# 近期新聞報導：https://pse.is/3dsp69
# *實習期間：* 2021/7/5 – 2021/8/27，共計8週
# *招募對象：* 大二以上或研究所學生，預計2-3人
# *工作內容：*
# 進行產業分析、市場調查、盡職調查，並支援同仁進行投資判斷
# 協助找尋潛在的投資標的，共同拜訪創辦團隊或投資人關係 (IR)、撰寫Call Memo
# 建立財務預估模型、提供對評估案件之估值看法
# 支援臨時任務
# *偏好條件：*
# 基礎財務、會計、商管知識與能力
# 具備行業分析與資本市場經驗
# 富有好奇心，願意接受挑戰，並達成任務
# *執行時間：* 申請截止：5/28 (五) 面試期間：6/2 (三) ~ 6/11 (五) 結果公告：6/16 (三)
# *申請：* 將履歷寄送至 leohsu@autai.com.tw
# *實習地點：* 新北市新店區
# *備註：* 時薪$160，完成實習計畫者有機會獲得推薦信
# 感謝各位對XChange招募的踴躍報名，
# 我們收到不少朋友表示非常有興趣加入團隊，…… 查看更多
# 【工作主要內容 - Seller program】
# -執行計劃舉措, 提高賣家的表現
# -分析活動和其他舉措業績…… 查看更多
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 今晚....我想來點有挑戰的!
# /…… 查看更多
# 角色和責任:
# •瞭解並遵守公司的檔案控制流程(包括敏捷流程)以及當地物質審查流程
# •領導任何A & P (廣告和宣傳)資產的本地化和翻譯工作
# •帶領所有創意資產需求季度清單匯編, 與公司合作
# •品牌通訊-直覺的使命, 品牌歷史, 視覺品牌語言(VBL)
# •管理外科醫生, 醫院和病人事件的後勤工作(預算, AV住宿等) )
# •管理與活動, 預售和釋出相關的SFDC /自動化利用
# •全年協調和執行銷售/商業內部會議
# •審查和註冊新供應商, 付款發票管理
# •管理所有分配的競選預算
# 技能, 經驗, 教育和培訓需要學士學位或同等學位• 2多年的會議或活動組織經驗, 醫療裝置產業體驗加
# •醫療裝置或制藥公司的項目管理經驗優先
# •在領導一個中期項目方面表現出成功
# •能夠管理多項任務
# •跨職能工作的人際交流技能
# •需要流利的口頭和書面英語
# •需要電腦技能(微軟單詞, Excel, PowerPoint)
# •旅行能力30 %
# 薪資待遇：月薪50,000以上
# 工作時間：9:00-18:00; 周休二日、必要時配合加班及出差
# 應徵方式：請將履歷投遞至104或IST.HR@intusurg.com
# https://www.104.com.tw/company/1a2x6bl25t
# 澳台國際投資定位為一小型PE Fund，投資範圍涵蓋台灣市場的財務性、策略性股權投資，關注產業包括農食供應鏈、垂直型電商、餐廳科技等。另外，澳台於2020年底收購上櫃公司夠麻吉(8472.TWO) 55%股權，亦協助佈局未來發展的第二成長曲線。
# 公司背後為創辦澳洲品牌Nature’s Care的吳氏家族，家族在澳洲當地經商30年，藉由澳洲當地的有機原材料生產出優質的保養、保健品，並佈局至全球。此外，家族也在澳洲自營酒莊、橄欖田，並致力推廣其衍伸食品。
# 近期新聞報導：https://pse.is/3dsp69
# *實習期間：* 2021/7/5 – 2021/8/27，共計8週
# *招募對象：* 大二以上或研究所學生，預計2-3人
# *工作內容：*
# 進行產業分析、市場調查、盡職調查，並支援同仁進行投資判斷
# 協助找尋潛在的投資標的，共同拜訪創辦團隊或投資人關係 (IR)、撰寫Call Memo
# 建立財務預估模型、提供對評估案件之估值看法
# 支援臨時任務
# *偏好條件：*
# 基礎財務、會計、商管知識與能力
# 具備行業分析與資本市場經驗
# 富有好奇心，願意接受挑戰，並達成任務
# *執行時間：* 申請截止：5/28 (五) 面試期間：6/2 (三) ~ 6/11 (五) 結果公告：6/16 (三)
# *申請：* 將履歷寄送至 leohsu@autai.com.tw
# *實習地點：* 新北市新店區
# *備註：* 時薪$160，完成實習計畫者有機會獲得推薦信
# 感謝各位對XChange招募的踴躍報名，
# 我們收到不少朋友表示非常有興趣加入團隊，
# 但這週面對疫情升溫，各公司都不斷緊急應變，
# 也因而希望能延長報名時間，以便準備提供書面資料
# XChange經過內部討論後，決定在這次夏季招募，
# 增加各組的招募需求，並將報名時間延至5/22(六)23:59截止！
#  快速了解各組別徵才說明  shorturl.at/cqEKT
# 希望大家在安全防疫之餘也心動馬上行動，
# 錯過這次就要再等至少半年後囉！
# 2021/05/22 (六) 23:59  報名截止
# 2021/05/24 (一) 各組組長聯繫通過履歷初選的人選 (將透過FB Messenger聯繫)
# 2021/06/06 (日) 人才組夥伴透過email寄送錄取通知
# 溫馨小提醒！
#     錄取者將優先以 FB Messenger 與 email 通知，
#     請留意FB陌生訊息唷！
# 【工作主要內容 - Seller program】
# -執行計劃舉措, 提高賣家的表現
# -分析活動和其他舉措業績
# -支援和優化程式, 例如節目唱片流程, 材料準備等
# 【工作條件】
# - 具備責任感、細心、耐心
# - 具備數據處理能力 (Excel/Google sheet)
# - 一周至少可安排3個整天
# 【加分條件】
# - 有程式語言能力者佳 (eg. SQL, Tableau, Python)
# - 優先考慮可長期配合者(半年以上)
# 【薪資】
# 每小時170美元
# 請將簡歷傳送至jay.tseng@shopee.com, 謝謝!
# 奧迪福斯汽車2021 H2 實習計劃開始囉! ! !
# 歡迎對汽車產業有興趣的你/妳一起進入外商的懷抱 !
# 工作職缺與徵求條件：合約期間須為大學或碩士在學學生。
#  實習期間： 2021年 6月中或 7月初起能配合為期至少半年至一年，每週能到班三個工作天以上，公司上班時間為9:00-18:00（含一小時休息）。
# 實習津貼：月薪$25,000元，並依出勤比率進行調整。
# 工作地點：多數職缺上班地點位於台北信義區辦公室，少數職缺位於汐止訓練中心，投遞前請務必詳細閱讀職缺描述。
# 應徵方式：請透過104人力銀行網站搜尋職缺進行應徵，並檢附中英文履歷，審查採隨到隨審制，合適者將會進行後續面談流程。
# 有任何問題歡迎私訊粉絲專頁！
# 104人力銀行傳送門：
# https://www.104.com.tw/company/dclyhyo
# 最後提醒大家，近日疫情嚴峻，來訪面試時也要留意自身健康狀況，並記得日常生活要勤洗手、戴口罩，好好保護自己，也保護大家，共同為防疫盡一份心力！
