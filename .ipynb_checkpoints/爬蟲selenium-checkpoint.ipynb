# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup

# %%
def d(line):
    l = '.'.join(line.split())
    return l

# %%
#關閉通知
options = webdriver.ChromeOptions()
prefs = {'profile.default_content_setting_values':{'notifications': 2}}
options.add_experimental_option('prefs', prefs)

#打開瀏覽器
driver = webdriver.Chrome('./chromedriver')
driver.get("http://www.facebook.com")

# %%
email = input("請輸入ㄓ")
password = 'u83fu68917'

# %%
#登入by class name
input1 = driver.find_element_by_class_name('inputtext._55r1._6luy')
input1.send_keys(email)

input2 = driver.find_element_by_class_name('inputtext._55r1._6luy._9npi')
input2.send_keys(password)

driver.find_element_by_class_name('_42ft._4jy0._6lth._4jy6._4jy1.selected._51sy').click()

# %%
input_1 = driver.find_element_by_css_selector('#email')
input_1.send_keys('amyyang20000107@yahoo.com.tw')

# %%
input_2 = driver.find_element_by_css_selector("input[type='password']")
input_2.send_keys('u83fu68917')
driver.find_element_by_css_selector("button[name='login']").click()

# %%
#移動到下面
driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')

# %%
# go to specific page
url = 'https://www.facebook.com/groups/808065716041098/?multi_permalinks=1845867072260952%2C1845828008931525%2C1845825975598395%2C1845768885604104%2C1845714092276250&notif_id=1619506442367667&notif_t=group_activity&ref=notif'
driver.get(url)

# %%
import pandas as pd
from time import sleep

# %%
c= driver.find_element_by_class_name(d('o9v6fnle cxmmr5t8 oygrvhab hcukyx3x c1et5uql ii04i59q'))
print(c)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="f7d722161bf0c3832254ff2dd4c621c0", element="9ec7c99c-ea1f-434b-a12f-f4f0ea91b532")>

# %%
c= driver.find_elements_by_class_name(d('o9v6fnle cxmmr5t8 oygrvhab hcukyx3x c1et5uql ii04i59q'))
for i in c:
    print(i.text)
# Out:
# 本說明會以招募具東協國籍（泰國、越南、柬埔寨、菲律賓、馬來西亞、印尼）同學參與，惟現場提供政大學生（含台籍本地生）簡單的履歷健檢服務，以及對中租迪和相關職缺有興趣同學諮詢。
# 聯合報名系統：https://reurl.cc/a5Kre4
# 實習活動介紹：https://reurl.cc/2bR84O
# 職缺介紹：https://www.104.com.tw/job/793nx
# --
# #大東協實習就業計畫GAIEP
# 本實習機會屬於「大東協實習就業計畫(GAIEP)」重要的一環，專門為了在台就學的東南亞同學所設計，希望網羅具財務/管理/科技相關專長的人選，透過課餘時間，深度體驗金融租賃業的業務/後勤工作。除了增加同學的職場經驗，表現優秀者更可以優先在完成學業後，由公司推薦母國或台灣的就業機會。
# #關於中租控股
# 中租Chailease是台灣最大的金融租賃品牌，透過生產設備「以租代買」的方案，協助中小企業達成更快的擴展；而除了中小企業的資金服務外，也橫跨個人支付、再生能源、租車/保險等相關業務。中租在東協5個國家成立獨營或合營公司，複製在台成功的商業模式，不只承接台商/外商的需求，也積極耕耘在地企業市場。
# #我們在尋找這樣的你
# ■在台就讀大學/研究所的東協(ASEAN)國家同學
# ■書面與口語皆能以中/英/母語無礙溝通
# ■對金融租賃產業或跨國公司充滿好奇
# ■熱情與活力，能在例行的工作中給予同事/主管驚喜
# #我們徵求的專長/組別
# ■財務專長(Finance)：處理海外據點會計帳務及資產/支出分析
# ■資訊專長(IT)：處理公司內部資訊系統維護及各單位需求
# ■人力資源專長(HR)：處理海外人事文件及派外人員相關手續/訓練
# #加入我們你可以獲得
# ■合理的薪資待遇與有保障的工作環境
# ■和具有專業的同事共事的機會
# ■難忘的職場經驗與自己的專案作品
# ※為符合主管機關規定，我們接受：
# 1.兼職(學期間每週不超過20小時) 或
# 2.全職(暑假期間)的實習。請於申請時說明欲參加的組別、時間及目前在台證件情況。
# --
# # GAIEP:
# ...

# %%
driver.forward()#下一頁
driver.back()

# %%
c= driver.find_elements_by_class_name(d('oajrlxb2 g5ia77u1 qu0x051f esr5mh6w e9989ue4 r7d6kgcz rq0escxv nhd2j8a9 nc684nl6 p7hjln8o kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x jb3vyjys rz4wbd8a qt6c0cv9 a8nywdso i1ao9s8h esuyzwwr f1sip0of lzcic4wl oo9gr5id gpro0wi8 lrazzd5p'))
for i in c:
    if i.text =='查看更多':
        
        try :
            i.click()
        except:
            print(i.text)
# Out:
# 查看更多

# %%
soup = BeautifulSoup(driver.page_source,'html.parser')

# %%
total = soup.find_all(class_='bi6gxh9e')
post=[]

for i in total:
    post.append(i.text)

# %%
frame = soup.find_all(class_='bi6gxh9e')
for i in range(0,len(frame)):
    if (frame[i].find('span'))!='':
        print(frame[i].find('span').text)
    #print(frame[i])
    #print(frame[i].find('span').text)
# Out:
# /工讀/工作資訊交流版 Jobs and Internships
# 私密社團  · 2.0 萬位成員
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-6772fa7b9417> in <module>
#       2 for i in range(0,len(frame)):
#       3     if (frame[i].find('span'))!='':
# ----> 4         print(frame[i].find('span').text)
#       5     #print(frame[i])
#       6     #print(frame[i].find('span').text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
text = driver.find_element_by_class_name(d('oajrlxb2 g5ia77u1 qu0x051f esr5mh6w e9989ue4 r7d6kgcz rq0escxv nhd2j8a9 nc684nl6 p7hjln8o kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x jb3vyjys rz4wbd8a qt6c0cv9 a8nywdso i1ao9s8h esuyzwwr f1sip0of lzcic4wl oo9gr5id gpro0wi8 lrazzd5p'))

# %%
text.text
# Out:
# '曾于芳'

# %%
text = driver.find_element_by_class_name('bi6gxh9e')

# %%
text.text
# Out:
# 'NCCU政治大學實習\x08/工讀/工作資訊交流版 Jobs and Internships'

# %%
text
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-47-3f178d1056b6> in <module>
# ----> 1 driver.find_element_by_class_name(d('oajrlxb2 g5ia77u1 qu0x051f esr5mh6w e9989ue4 r7d6kgcz rq0escxv nhd2j8a9 nc684nl6 p7hjln8o kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x jb3vyjys rz4wbd8a qt6c0cv9 a8nywdso i1ao9s8h esuyzwwr f1sip0of lzcic4wl oo9gr5id gpro0wi8 lrazzd5p')).click()
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# ...
