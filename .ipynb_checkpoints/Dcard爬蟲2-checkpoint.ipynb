# %% [markdown]
# # Dcard爬蟲留言

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as npp

# %%
# 需要有文章號碼
cip='235807969'#國泰
kg="235697367" #凱基

# %% [markdown]
# # 主程式

# %%
def crawl(postnum):
    dic={}
    count=0

    url2 = f"https://www.dcard.tw/service/api/v2/posts/{postnum}"
    ww = requests.get(url2)
    ww = ww.json()
    total_num = ww['commentCount']
    
    t = total_num//100
    for j in range(0,t+1): 
        url=(f"https://www.dcard.tw/service/api/v2/posts/{postnum}/comments?after={(j*100)}&limit=100" )#limit100最多取100則回應
        web = requests.get(url)
        w = web.json()

        for i in range(0,len(w)):
            if 'content' in w[i]:
                content = (w[i]['content'])
                floor = w[i]['floor']
                if 'school' in w[i]:
                    school = w[i]['school']
                else:
                    school = '匿名'
                dic[floor] = [content,school]
            
            else:
                count+=1
            
    df = pd.DataFrame.from_dict(dic,orient='index',columns=['內容','學校'])
    print(f'總共有{len(df.index)}則回應,{count}則被刪掉的回應')
    return df

# %%
data = crawl(cip)
# Out:
# 總共有1104則回應,49則被刪掉的回應

# %%
data[900:]
# Out:
#                                內容      學校
# 938                       B937 愛你  國立中央大學
# 939                 集氣QAQ\n不要取消啊啊  國立成功大學
# 940                  今天有人收到offer嗎   Dave_
# 941                 今年+29本土 怕爆0.0  國立中央大學
# 942   想問如果之後疫情真的很嚴重 有可能不取消但是wfh嗎🥺  國立政治大學
# ...                           ...     ...
# 1149  請問有期貨、投信、投顧、產險的同學收到offer了嗎？  國立清華大學
# 1150           收到 數金 企業架構科口頭offer      匿名
# 1151               B1149 投信上面有人收到  國立中央大學
# 1152         同問KOKO科\n請問有人收到通知了嗎😭  國立政治大學
# 1153         收到 金控數金數據科技科 口頭offer  國立政治大學
#
# [204 rows x 2 columns]

# %% [markdown]
# ## 利用關鍵字搜尋

# %%
keyword = input('要找什麼關鍵字？')
post = data
post[post['內容'].str.contains(keyword)]
# Out:
# 要找什麼關鍵字？投顧
#                            內容      學校
# 207            Cccccc有人投顧收到嗎😭  國立政治大學
# 259                  投顧有人收到了嗎  國立中山大學
# 282                  有人收到投顧的嗎  國立中央大學
# 346                      卡投顧🥺  國立政治大學
# 352        B350 看留言目前投顧沒有人收到耶    東吳大學
# 368         B367 期貨 投顧 產險 ^ ^  國立中央大學
# 481  剛剛才找到這個同溫層\n請問投顧收到了嗎 好緊張    東吳大學
# 487       B481 我也投顧 目前看來都還沒收到    東吳大學
# 550                    卡投顧...  國立政治大學
# 556          看來期貨、產險、投顧還是沒消息⋯  國立清華大學
# 565                       卡投顧    東吳大學
# 653         投顧接到電話約時間，正式信會晚點寄  國立臺灣大學
