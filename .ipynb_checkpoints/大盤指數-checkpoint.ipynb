# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
import requests as web
import datetime

# %% [markdown]
# ## 讀取期貨未平倉

# %%
df = pd.read_html("https://www.taifex.com.tw/cht/3/futContractsDate")

# %%
f = df[3]
f = f.iloc[0:12,1:]
for i in range(3,9):
    f=f.drop(index=i)

# %%
f
# Out:
#    Unnamed: 1_level_0 Unnamed: 2_level_0 交易口數與契約金額                    \
#    Unnamed: 1_level_1 Unnamed: 2_level_1        多方                空方
#                  商品名稱                身份別        口數       契約金額     口數
# 0                臺股期貨                自營商     12653   43182180  11916
# 1                臺股期貨                 投信      1975    6752312   1511
# 2                臺股期貨                 外資     71090  242691263  74596
# 9              小型臺指期貨                自營商     14494   12349659  15630
# 10             小型臺指期貨                 投信         0          0      0
# 11             小型臺指期貨                 外資     94438   80589449  97905
#
#                               未平倉餘額
#                多空淨額              多方      空方      多空淨額
#          契約金額    口數      契約金額    口數 契約金額 口數 契約金額   口數 契約金額
# 0    40680005   737   2502175     -    -  -    -    -    -
# 1     5148887   464   1603425     -    -  -    -    -    -
# 2   254660802 -3506 -11969539     -    -  -    -    -    -
# 9    13313366 -1136   -963707     -    -  -    -    -    -
# 10          0     0         0     -    -  -    -    -    -
# 11   83556302 -3467  -2966853     -    -  -    -    -    -

# %%
today = str(datetime.date.today())
today = today[0:4]+today[5:7]+today[8:10]
today
# Out:
# '20210416'

# %%
margin = pd.read_html("https://www.twse.com.tw/exchangeReport/MI_MARGN?response=html&date=%s&selectType=MS"%(today))[0]

# %%
m = pd.read_html("https://www.twse.com.tw/exchangeReport/MI_MARGN?response=html&date=20210415&selectType=MS")[0]

# %%
m.columns['增減']=m.前日餘額-m.今日餘額
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-bdee75c83171> in <module>
# ----> 1 m.columns['增減']=m.前日餘額-m.今日餘額
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute '前日餘額'

# %%
pc = pd.read_html("https://www.taifex.com.tw/cht/3/pcRatio")[3]

# %%
pc
# Out:
#            日期   賣權成交量   買權成交量  買賣權成交量比率%  賣權未平倉量  買權未平倉量  買賣權未平倉量比率%
# 0   2021/4/16  390312  385524     101.24  341705  225880      151.28
# 1   2021/4/15  350937  339821     103.27  309323  202957      152.41
# 2   2021/4/14  907420  911296      99.57  243117  166907      145.66
# 3   2021/4/13  576146  532583     108.18  356300  259904      137.09
# 4   2021/4/12  352493  330036     106.80  334263  251427      132.95
# 5    2021/4/9  296121  293863     100.77  293517  228535      128.43
# 6    2021/4/8  316653  283902     111.54  263495  194892      135.20
# 7    2021/4/7  422868  439153      96.29  196528  151059      130.10
# 8    2021/4/6  413187  374567     110.31  300087  224473      133.69
# 9    2021/4/1  260931  243273     107.26  233998  184188      127.04
# 10  2021/3/31  495630  533282      92.94  168107  139503      120.50
# 11  2021/3/30  422515  352273     119.94  341427  239788      142.39
# 12  2021/3/29  389760  396654      98.26  318945  225292      141.57
# 13  2021/3/26  383597  344962     111.20  263742  205837      128.13
# 14  2021/3/25  297353  295719     100.55  210868  179805      117.28
# 15  2021/3/24  572422  538172     106.36  149872  125593      119.33
# 16  2021/3/23  384437  397338      96.75  271371  249400      108.81
# 17  2021/3/22  378409  352204     107.44  246796  218669      112.86
# 18  2021/3/19  369551  399828      92.43  204342  201660      101.33
# 19  2021/3/18  318678  328274      97.08  174029  146853      118.51
# 20  2021/3/17  643634  584907     110.04  105918   89180      118.77

# %%
option = pd.read_html("https://www.taifex.com.tw/cht/3/optDailyMarketSummary")

# %%
buy_option = option[4]

# %%
put_option = option[7]
